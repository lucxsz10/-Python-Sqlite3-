# %%
import sqlite3 as sql 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
conn = sql.connect('ETL.db')
cursor = conn.cursor()

# %%
df = pd.read_sql_query("SELECT * FROM Users", conn)
df

# %%
url = "https://dolarapi.com/v1/dolares"
response = requests.get(url)
if response.status_code != 200:
    raise Exception("Failed to load page {}".format(url))
data = response.json()
data
# Out:
# [{'moneda': 'USD',
#   'casa': 'oficial',
#   'nombre': 'Oficial',
#   'compra': 1410,
#   'venta': 1460,
#   'fechaActualizacion': '2026-01-20T17:00:00.000Z'},
#  {'moneda': 'USD',
#   'casa': 'blue',
#   'nombre': 'Blue',
#   'compra': 1485,
#   'venta': 1505,
#   'fechaActualizacion': '2026-01-20T20:59:00.000Z'},
#  {'moneda': 'USD',
#   'casa': 'bolsa',
#   'nombre': 'Bolsa',
#   'compra': 1470.3,
#   'venta': 1472.9,
#   'fechaActualizacion': '2026-01-20T20:59:00.000Z'},
#  {'moneda': 'USD',
#   'casa': 'contadoconliqui',
#   'nombre': 'Contado con liquidación',
#   'compra': 1516.9,
#   'venta': 1517.7,
#   'fechaActualizacion': '2026-01-20T20:59:00.000Z'},
#  {'moneda': 'USD',
#   'casa': 'mayorista',
#   'nombre': 'Mayorista',
#   'compra': 1425.5,
#   'venta': 1434.5,
#   'fechaActualizacion': '2026-01-20T15:36:00.000Z'},
#  {'moneda': 'USD',
#   'casa': 'cripto',
#   'nombre': 'Cripto',
#   'compra': 1521,
#   'venta': 1521.1,
#   'fechaActualizacion': '2026-01-20T20:59:00.000Z'},
#  {'moneda': 'USD',
#   'casa': 'tarjeta',
#   'nombre': 'Tarjeta',
#   'compra': 1833,
#   'venta': 1898,
#   'fechaActualizacion': '2026-01-20T17:00:00.000Z'}]
